# %%
import access_control as ac
import media_engine as me

CONTROL_NUM = 9
FAVORITE_ARTIST = "PARTYNEXTDOOR"

# %%
print("--- Exercise 1: Secure Access ---")
level = ac.compute_access_level(CONTROL_NUM)
decision = ac.validate_access(level)
print(f"Access Level: {level}")
print(f"Final Decision: {decision}")
# Out:
# --- Exercise 1: Secure Access ---
# Authorization Started
# Authorization Completed
# Access Level: 40
# Final Decision: ACCESS DENIED

# %%
def signal_shutdown(power, count=0):
    if power <= 0: return count
    print(f"Current signal strength: {power}")
    return signal_shutdown(power - 1, count + 1)

print("--- Exercise 2: Recursive Signal Shutdown ---")
# Power = 9 + 6 = 15
total_calls = signal_shutdown(15)
print (f"Total recursive calls: {total_calls}")
# Out:
# --- Exercise 2: Recursive Signal Shutdown ---
# Current signal strength: 15
# Current signal strength: 14
# Current signal strength: 13
# Current signal strength: 12
# Current signal strength: 11
# Current signal strength: 10
# Current signal strength: 9
# Current signal strength: 8
# Current signal strength: 7
# Current signal strength: 6
# Current signal strength: 5
# Current signal strength: 4
# Current signal strength: 3
# Current signal strength: 2
# Current signal strength: 1
# Total recursive calls: 15

# %%
print("--- EXERCISE 3: STREAMING MEDIA ANALYTICS ---")

CONTROL_NUM = 9
FAVORITE_ARTIST = "LAUFEY"
SHARED_LIMIT = CONTROL_NUM + len(FAVORITE_ARTIST) # 9 + 6 = 15

total_plays, num_records, counts = me.run_analytics(SHARED_LIMIT)

print(f"Computed Stream Limit: {SHARED_LIMIT}")
print(f"Generated Play Counts (Squares of Evens): {counts}")
print(f"Total Plays: {total_plays}")
print(f"Number of Records Processed: {num_records}")
# Out:
# --- EXERCISE 3: STREAMING MEDIA ANALYTICS ---
# Computed Stream Limit: 15
# Generated Play Counts (Squares of Evens): [0, 4, 16, 36, 64, 100, 144, 196]
# Total Plays: 560
# Number of Records Processed: 8
